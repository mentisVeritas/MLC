# %% [markdown]
# P or p = number of favourable choices / total number of choices

# %% [markdown]
# 2 blue and 3 red marbles

# %%
1 / 5
# Out:
# 0.2

# %% [markdown]
# # Central Limit Theorem

# %% [markdown]
# The means
# drawn from multiple samples will resemble the familiar bell-shaped normal
# curve (see “Normal Distribution”), even if the source population is not normally
# distributed, provided that the sample size is large enough and the departure of
# the data from normality is not too great.

# %% [markdown]
# ## Demonstration

# %%
import numpy as np
import matplotlib.pyplot as plt

sample_sizes = [10, 50, 100]
all_sample_means = []

np.random.seed(42)

for size in sample_sizes:
    sample_means = [np.mean(np.random.randint(-40, 40, size))
                    for _ in range(1000)]
    all_sample_means.append(sample_means)

fig, axes = plt.subplots(2, 2, figsize=(10, 8))

for ax, means, size in zip(axes.flatten(), all_sample_means, sample_sizes):
    ax.hist(means, bins=20, density=True, alpha=0.75,
            color='purple', edgecolor='black')
    ax.set_title(f"Sample size = {size}")
    ax.set_xlabel("Sample Mean")
    ax.set_ylabel("Density")
    ax.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Law of large numbers

# %% [markdown]
# In probability theory, the law of large numbers is a mathematical law that states that the average of the results obtained from a large number of independent random samples converges to the true value, if it exists.

# %% [markdown]
# # Probabilities

# %% [markdown]
# ## Definitions

# %% [markdown]
# - **Event**: A thing that you can observe whether it happens or not.
# - **Probability**: The chance that an event happens, on a scale from 0 (cannot happen) to 1 (always happens). Denoted P(event).
# - **Probability universe**: The probability space where all the events you are considering can either happen or not happen.
# - **Mutually exclusive events**: If one event happens, then the other event cannot happen (e.g., you cannot roll a dice that is both 5 and 1).
# - **Independent events**: If one event happens, it does not affect the probability that the other event happens (e.g., the weather does not affect the outcome of a dice roll).
# - **Dependent events**: If one event happens, it changes the probability that the other event happens (e.g., the weather affects traffic outcomes).
# - **Conjunctive probability (a.k.a. joint probability)**: The probability that all events happen.
# - **Disjunctive probability**: The probability that at least one event happens.
# - **Conditional probability**: The probability that one event happens, given another event happened.

# %% [markdown]
# ## Complement Rule: Probability of events not happening

# %% [markdown]
# - **Formula**: P(A') = 1 - P(A)
# - **Example**: The probability of basketball player Stephen Curry successfully shooting a three-pointer is 0.43. The complement, the probability that he misses, is 1 - 0.43 = 0.57.

# %% [markdown]
# ## Multiplication Rules: Probability of both events happening

# %% [markdown]
# ### Mutually exclusive events

# %% [markdown]
# - **Formula**: P(A ∩ B) = 0
# - **Example**: If the probability of it being sunny at midday is 0.3 and the probability of it raining at midday is 0.4, the probability of it being sunny and rainy is 0, since these events are mutually exclusive.

# %% [markdown]
# ### Independant Events

# %% [markdown]
# - **Formula**:  P(A ∩ B) = P(A) * P(B)
# - **Example**: If the probability of it being sunny at midday is 0.3 and the probability of your favorite soccer team winning their game today is 0.6, the then probability of it being sunny at midday and your favorite soccer team winning their game today is 0.3 * 0.6 = 0.18.

# %% [markdown]
# ## Addition Rules: Probability of at least one event happening

# %% [markdown]
# ### Mutually exclusive events

# %% [markdown]
# - **Formula**: P(A ∪ B) = P(A) + P(B)
# - **Example**: If the probability of it being sunny at midday is 0.3 and the probability of it raining at midday is 0.4, the probability of it being sunny or rainy is 0.3 + 0.4 = 0.7, since these events are mutually exclusive.

# %% [markdown]
# ## Independant Events

# %% [markdown]
# - **Formula**: P(A ∪ B) = P(A) + P(B) - P(A ∩ B)
# - **Example**: If the probability of it being sunny at midday is 0.3 and the probability of your favorite soccer team winning their game today is 0.6, the then probability of it being sunny at midday or your favorite soccer team winning their game today is 0.3 + 0.6 - (0.3 * 0.6) = 0.72.

# %% [markdown]
# ## Independance Test

# %% [markdown]
# P(A ∩ B) = P(A)P(B) <br>
# P(A|B) = P(A)<br>
# P(B|A) = P(B)<br>

# %% [markdown]
# ## Conditional Probability

# %% [markdown]
# Probability of A, given that B occurred.

# %% [markdown]
#  P (A|B) = P (A ∩ B)/P (B)

# %% [markdown]
# I roll a fair die. Let A be the event that the outcome is an odd number, i.e., A={1,3,5}. Also let B be the event that the outcome is less than or equal to 3, i.e., B={1,2,3}. What is the probability of A, P(A)? What is the pr|obability of A given B, P(A|B)?

# %% [markdown]
# ## Bayes' Theorem

# %% [markdown]
# $P(A \mid B) = \frac{P(B \mid A)\, P(A)}{P(B)}$

# %% [markdown]
# OR

# %% [markdown]
# $P(A \mid B) =
# \frac{P(B \mid A)\, P(A)}
# {P(B \mid A)\, P(A) + P(B \mid A^c)\, P(A^c)}$

# %% [markdown]
# ### Example

# %% [markdown]
# - 1% of women have breast cancer (and therefore 99% do not).
# - 80% of mammograms detect breast cancer when it is there (and therefore 20% miss it).
# - 9.6% of mammograms detect breast cancer when it’s not there (and therefore 90.4% correctly return a negative result).

# %%
P(A) - probability of having a cancer
P(A|B) - probability of having a cancer given positive test
P(B|A) - chance of positive test given that you have a cancer

# %%
P(A) = 0.01
P(A|B) = ?
P(B|A) = 0.8

# %%
P(A|B) = P(B|A) * P(A) / (P(B|A) * P(A) + P(B|not A) * P(not A))

# %%
0.8 * 0.01 / ((0.8 * 0.01) + (0.096*0.99))
# Out:
# 0.07763975155279504

# %% [markdown]
# # Law of Total Probability

# %% [markdown]
# I have three bags that each contain 100 marbles:
#
# - Bag 1 has 75 red and 25 blue marbles;
# - Bag 2 has 60 red and 40 blue marbles;
# - Bag 3 has 45 red and 55 blue marbles.
# <br>
#
# I choose one of the bags at random and then pick a marble from the chosen bag, also at random. What is the probability that the chosen marble is red?

# %%
(0.75 + 0.6 + 0.45)/3
# Out:
# 0.6

# %% [markdown]
# $P(B) = \sum_{i=1}^n P(B∣A_i)P(A_i)$

# %% [markdown]
# # Practice

# %% [markdown]
# 1. In a survey of 100 students: 65 use Netflix, 45 use Disney+, and 30 use both services.
#     * What's P(uses Netflix OR Disney+)?
#     * What's P(uses ONLY Netflix)?
#     * What's P(uses neither service)?
# 2. A factory has two production lines: Line A (95% success rate) and Line B (98% success rate). The lines operate independently.
#     * What's the probability both lines produce a good item?
# 3. Your email provider routes messages through 3 servers:<br>
# Server A (handles 50% of emails): 2% spam detection error<br>
# Server B (handles 30% of emails): 5% spam detection error<br>
# Server C (handles 20% of emails): 1% spam detection error<br>
#     * What's the overall probability an email is incorrectly classified?
# 4. A sushi restaurant offers orders: salmon, tuna, or eel. You and a friend each order randomly.
#     * What's the probability you both order salmon?
# 5. A pizza shop's data shows: 60% of orders are large pizzas, 40% include drinks, 25% are both large pizzas with drinks. Delivery time is uniform between 20-40 minutes.
#     * Are "large pizza" and "includes drinks" independent?
#     * What's P(large pizza OR drinks)?
# 6. You're randomly assigned 2 coding problems from a bank of 10 (4 easy, 4 medium, 2 hard). You solve easy problems 90% of the time, medium 60%, and hard 30%. If you solved both problems, what's the probability both were easy?

# %%
P(both easy|solved both) = ?

# %%
P(solved both) = E and E, E and M, E and H, M and M, M and H, H and H
